# %% [markdown]
# <a href="https://colab.research.google.com/github/john-d-noble/Auto-Lending-Startup-Case-Study-Data-Science-Leadership/blob/master/ESG_Market_Weighted_Swarm_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python program to illustrate
# swarmplot using inbuilt data-set
# given in seaborn
  
# importing the required module
import seaborn
 
# use to set style of background of plot
seaborn.set(style="whitegrid")
 
# loading data-set
tips = seaborn.load_dataset("tips")

seaborn.swarmplot(x="day", y="total_bill", hue="smoker",
                   data=tips, palette="Set2", size=20, marker="D",
                   edgecolor="gray", alpha=.25)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 38.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 43.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 38.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# use to set style of background of plot
seaborn.set(style="whitegrid")
 


seaborn.swarmplot( x="market cap", y='combined total ESG',  hue="industry",
                   data=df, palette="Set2", size=20, marker="D",
                   edgecolor="gray", alpha=.25)

# %%
import pandas as pd
import seaborn 

 # reads the excel file

df = pd.read_excel("simple.xlsx")

#add column 
df.columns = ['industry', 'combined total ESG', 'market cap', 'marketcapBN'
              ]
df
# Out:
#                  industry  combined total ESG    market cap  marketcapBN
# 0  Communication Services           19.287826  2.783509e+12  2783.508842
# 1       Consumer Cyclical           19.371045  2.694440e+12  2694.440244
# 2      Consumer Defensive           24.123235  2.632174e+12  2632.173615
# 3                  Energy           32.723810  1.385105e+12  1385.105455
# 4      Financial Services           20.682727  3.540656e+12  3540.655743
# 5              Healthcare           21.203077  5.086357e+12  5086.356853
# 6             Industrials           24.040429  2.771650e+12  2771.649904
# 7             Real Estate           12.784138  9.099863e+11   909.986341
# 8              Technology           16.833571  8.260872e+12  8260.871624
# 9               Utilities           27.539286  9.668587e+11   966.858704

# %%
# libraries
import matplotlib.pyplot as plt
import seaborn as sns

# use the scatterplot function
sns.scatterplot(data=df, x="combined total ESG", y="marketcapBN", size="market cap", hue="industry", alpha=0.5, sizes=(1, 1000))


# Locate the legend outside of the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# show the graph
plt.show()
